# %% [markdown]
# This file executes the queries by connecting to the neo4j database and executing cypher commands.

# %%
from faker import Faker
import pandas as pd
import random
from tqdm import tqdm
import uuid
from neo4j import GraphDatabase
import subprocess

# %%
# ENTER NEO4J CREDENTIALS HERE
uri = "bolt://localhost:7687"  
username = "neo4j"  
password = "12345678"

# %%
# Start neo4j
try:
    command = "neo4j start"
    result = subprocess.run(command, shell=True, check=True, capture_output=True, text=True)
    print(result.stdout)
except subprocess.CalledProcessError as e:
    print("Failed to start neo4j - it may already be running")
# Out:
# Failed to start neo4j - it may already be running

# %%
# Establish connection to the Neo4j database
driver = GraphDatabase.driver(uri, auth=(username, password))

# Create query execution function
def execute_query(query):
    try:
        with driver.session() as session:
            result = session.run(query)
            return [record.data() for record in result]
    except Exception as e:
        print("An error occurred:", e)

# %% [markdown]
# # Query 1: Find the top 3 most cited papers of each conference.

# %% [markdown]
# ```python
# MATCH (c:CONFERENCE_WORKSHOP)<-[:PUBLISHED_IN]-(p:PAPER) # Match conferences and papers
# OPTIONAL MATCH (p)<-[:CITES]-(citing:PAPER) # Match papers citing other papers, if any
# WITH c, p, COUNT(citing) AS citationCount # Count the number of citations per paper
# ORDER BY c.name, citationCount DESC # Order by conference and citation count
# WITH c.name AS conferenceName, COLLECT({paper: p, citations: citationCount})[0..3] AS topPapers # Collect the top 3 papers per conference
# UNWIND topPapers AS topPaper # Unwind the top papers
# RETURN c.name AS Conference, topPaper.paper.title AS PaperTitle, topPaper.citations AS CitationCount
# ORDER BY Conference, CitationCount DESC

# %%
# Define the Cypher query to create Review nodes and relationships
top_papers_per_conference_query = """
MATCH (c:CONFERENCE_WORKSHOP)<-[:PUBLISHED_IN]-(p:PAPER)
OPTIONAL MATCH (p)<-[:CITES]-(citing:PAPER)
WITH c, p, COUNT(citing) AS citationCount
ORDER BY c.name, citationCount DESC
WITH c.name AS conferenceName, COLLECT({paper: p, citations: citationCount})[0..3] AS topPapers
UNWIND topPapers AS topPaper
RETURN conferenceName AS Conference, topPaper.paper.title AS PaperTitle, topPaper.citations AS CitationCount
ORDER BY Conference, CitationCount DESC
"""

# Execute the query and get the results
top_papers_per_conference = execute_query(top_papers_per_conference_query)
top_papers_per_conference
# Out:
# [{'Conference': 'Browning-Davis Workshop',
#   'PaperTitle': 'Yes professor itself step.',
#   'CitationCount': 16},
#  {'Conference': 'Browning-Davis Workshop',
#   'PaperTitle': 'Maintain present middle only speech voice spring.',
#   'CitationCount': 15},
#  {'Conference': 'Browning-Davis Workshop',
#   'PaperTitle': 'Democratic citizen rock some fight something take.',
#   'CitationCount': 13},
#  {'Conference': 'Gray-Johnson Conference',
#   'PaperTitle': 'Ground space among theory.',
#   'CitationCount': 15},
#  {'Conference': 'Gray-Johnson Conference',
#   'PaperTitle': 'Popular face wish various various note.',
#   'CitationCount': 15},
#  {'Conference': 'Gray-Johnson Conference',
#   'PaperTitle': 'Really law between.',
#   'CitationCount': 13},
#  {'Conference': 'Martinez, Perry and Smith Workshop',
#   'PaperTitle': 'I listen share environment chance bill usually.',
#   'CitationCount': 18},
#  {'Conference': 'Martinez, Perry and Smith Workshop',
#   'PaperTitle': 'Result risk half use.',
#   'CitationCount': 13},
#  {'Conference': 'Martinez, Perry and Smith Workshop',
#   'PaperTitle': 'Next clear late plan ten girl.',
#   'CitationCount': 12},
#  {'Conference': 'Perkins, Aguilar and Fowler Workshop',
#   'PaperTitle': 'Follow least peace front.',
#   'CitationCount': 13},
#  {'Conference': 'Perkins, Aguilar and Fowler Workshop',
#   'PaperTitle': 'Owner indicate could represent should ability argue.',
#   'CitationCount': 12},
#  {'Conference': 'Perkins, Aguilar and Fowler Workshop',
#   'PaperTitle': 'Heavy yes little product add effort anything.',
#   'CitationCount': 12},
#  {'Conference': 'Wang PLC Conference',
#   'PaperTitle': 'Education much we ok majority miss.',
#   'CitationCount': 14},
#  {'Conference': 'Wang PLC Conference',
#   'PaperTitle': 'Fine Congress modern fly him real should.',
#   'CitationCount': 13},
#  {'Conference': 'Wang PLC Conference',
#   'PaperTitle': 'Radio parent story almost TV.',
#   'CitationCount': 12}]

# %% [markdown]
# # Query 2: For each conference find its community: i.e., those authors that have published papers on that conference in, at least, 4 different editions.

# %% [markdown]
# ```python
# MATCH (a:AUTHOR)-[:WRITTEN_BY]->(p:PAPER)-[:PUBLISHED_IN]->(c:CONFERENCE_WORKSHOP) # Find authors, papers, and conferences
# WITH a, c.name AS conferenceName, c.edition AS edition # Collect author names, conference names and editions
# ORDER BY a, conferenceName, edition
# WITH a, conferenceName, COUNT(DISTINCT edition) AS editions # Count number of editions for each author
# WHERE editions >= 4 # Filter authors with at least 4 editions
# RETURN conferenceName AS Conference, a.name AS Author, editions
# ORDER BY Conference, Author

# %%
# Define the Cypher query to create Review nodes and relationships
conference_comunity_query = """
MATCH (a:AUTHOR)-[:WRITTEN_BY]->(p:PAPER)-[:PUBLISHED_IN]->(c:CONFERENCE_WORKSHOP)
WITH a, c.name AS conferenceName, c.edition AS edition
ORDER BY a, conferenceName, edition
WITH a, conferenceName, COUNT(DISTINCT edition) AS editions
WHERE editions >= 4
RETURN conferenceName AS Conference, a.name AS Author, editions
ORDER BY Conference, editions DESC
"""

# Execute the query and get the results
conference_comunity = execute_query(conference_comunity_query)
conference_comunity
# Out:
# [{'Conference': 'Browning-Davis Workshop',
#   'Author': 'Desiree Peck',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Theresa Schmitt',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Joy Sanchez',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Aaron Freeman',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Amanda Meyers',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Russell Howell',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Thomas Kramer',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Shawn Wallace',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Christy Manning',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Jacob Austin',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Adam Reed',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Samantha Cain',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Sarah Navarro',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Timothy Campbell',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Jo Atkinson',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'John Freeman',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Lori Banks',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Daniel Mcbride',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Steven Hernandez',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Bailey Wilson',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Kathy Jenkins',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'John Wilson',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Mark Schultz',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Andrea Parker',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Amanda Jones',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Ronald Shelton',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Charles Mitchell',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Geoffrey Floyd DDS',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Steven Perry',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Nicholas Smith',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Caroline Gonzalez',
#   'editions': 8},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Taylor Dunn',
#   'editions': 7},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Melissa Coleman',
#   'editions': 7},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Timothy Hughes',
#   'editions': 7},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Kimberly Garcia',
#   'editions': 7},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Robert Scott',
#   'editions': 7},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Tommy Morrison',
#   'editions': 7},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Cody Jensen',
#   'editions': 7},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Natalie Townsend',
#   'editions': 7},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Steven Gonzalez',
#   'editions': 7},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Daisy Walker',
#   'editions': 7},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'John King',
#   'editions': 7},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Erin Cochran',
#   'editions': 7},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': 'Sydney Potter',
#   'editions': 7},
#  {'Conference': 'Browning-Davis Workshop',
#   'Author': '

#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Melissa Coleman',
#   'editions': 7},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Timothy Hughes',
#   'editions': 7},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Kimberly Garcia',
#   'editions': 7},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Robert Scott',
#   'editions': 7},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Desiree Peck',
#   'editions': 7},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Tommy Morrison',
#   'editions': 7},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Theresa Schmitt',
#   'editions': 7},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Amanda Meyers',
#   'editions': 7},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Russell Howell',
#   'editions': 7},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Jennifer White',
#   'editions': 7},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Thomas Kramer',
#   'editions': 7},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Erin Cochran',
#   'editions': 7},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Alexis Marshall',
#   'editions': 7},
#  {'Conference': 'Wang PLC Conference', 'Author': 'Linda Gray', 'editions': 7},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Vicki Taylor',
#   'editions': 7},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Timothy Campbell',
#   'editions': 7},
#  {'Conference': 'Wang PLC Conference', 'Author': 'Gloria Webb', 'editions': 7},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Carolyn Savage',
#   'editions': 7},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Brett Parker',
#   'editions': 7},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Dr. Donald Hale PhD',
#   'editions': 7},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Elijah Washington',
#   'editions': 7},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Karen Lawrence',
#   'editions': 7},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Amanda Jones',
#   'editions': 7},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Mary Anderson',
#   'editions': 7},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Madison Evans',
#   'editions': 7},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Laura Gibson',
#   'editions': 7},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Douglas Brown',
#   'editions': 7},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Geoffrey Floyd DDS',
#   'editions': 7},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Katrina Nelson',
#   'editions': 7},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Marissa Clark',
#   'editions': 7},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Robert Krueger',
#   'editions': 7},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Nicholas Smith',
#   'editions': 7},
#  {'Conference': 'Wang PLC Conference', 'Author': 'Cody Jensen', 'editions': 6},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Natalie Townsend',
#   'editions': 6},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Daniel Mcbride',
#   'editions': 6},
#  {'Conference': 'Wang PLC Conference',
#   'Author': 'Kathy Jenkins',
#   'editions': 6}]

# %% [markdown]
# ## Query 3: Find the impact factors of the journals

# %% [markdown]
# ```python
# MATCH (j:JOURNAL)<-[:PUBLISHED_IN]-(p:PAPER)
# WHERE p.year IN [2021, 2022, 2023]
# OPTIONAL MATCH (p)<-[:CITES]-(citing:PAPER)
# WITH j, p.year AS publicationYear, COUNT(citing) AS citationCount, p
# RETURN j.name AS Journal,
#        CASE WHEN SUM(CASE WHEN publicationYear IN [2021, 2022] THEN 1 ELSE 0 END) = 0 THEN 0 # checks if papers published in year
#             ELSE (SUM(CASE WHEN publicationYear = 2023 THEN citationCount ELSE 0 END) * 1.0 / # calculate impact factor of jounrals
#                   SUM(CASE WHEN publicationYear IN [2021, 2022] THEN 1 ELSE 0 END))
#        END AS citationRatio

# %%
# Define the Cypher query to create Review nodes and relationships
impact_factor_query = """
MATCH (j:JOURNAL)<-[:PUBLISHED_IN]-(p:PAPER)
WHERE p.year IN [2021, 2022, 2023]
OPTIONAL MATCH (p)<-[:CITES]-(citing:PAPER)
WITH j, p.year AS publicationYear, COUNT(citing) AS citationCount, p
RETURN j.name AS Journal, 
       CASE WHEN SUM(CASE WHEN publicationYear IN [2021, 2022] THEN 1 ELSE 0 END) = 0 THEN 0 
            ELSE (SUM(CASE WHEN publicationYear = 2023 THEN citationCount ELSE 0 END) * 1.0 / 
                  SUM(CASE WHEN publicationYear IN [2021, 2022] THEN 1 ELSE 0 END)) 
       END AS citationRatio
"""

# Execute the query and get the results
impact_factor = execute_query(impact_factor_query)
impact_factor
# Out:
# [{'Journal': 'Ware, Fowler and Garcia Journal',
#   'citationRatio': 0.3072916666666667},
#  {'Journal': 'York, Foster and Johnston Journal',
#   'citationRatio': 0.10857142857142857}]

# %% [markdown]
# # Query 4: Find the h-indexes of the authors in your graph

# %%
# Define the Cypher query to create Review nodes and relationships
h_index_query = """
MATCH (a:AUTHOR)-[:WRITTEN_BY]->(p:PAPER)
OPTIONAL MATCH (p)<-[:CITES]-(citing:PAPER)
WITH a, p, COUNT(citing) AS citationCount
ORDER BY a.name, citationCount DESC
WITH a.name AS Author, COLLECT(citationCount) AS citations
UNWIND range(0, SIZE(citations) - 1) AS i
WITH Author, i + 1 AS rank, citations[i] AS citationCount
WHERE citationCount >= rank
RETURN Author, MAX(rank) AS h_index
ORDER BY h_index DESC
"""

# Execute the query and get the results
h_index = execute_query(h_index_query)
h_index
# Out:
# [{'Author': 'Alexis Marshall', 'h_index': 10},
#  {'Author': 'Gloria Webb', 'h_index': 10},
#  {'Author': 'Katrina Nelson', 'h_index': 10},
#  {'Author': 'Lauren Castillo', 'h_index': 10},
#  {'Author': 'Linda Garcia', 'h_index': 10},
#  {'Author': 'Mark Schultz', 'h_index': 10},
#  {'Author': 'Ronald Shelton', 'h_index': 10},
#  {'Author': 'Russell Howell', 'h_index': 10},
#  {'Author': 'Trevor Hampton', 'h_index': 10},
#  {'Author': 'Adam Reed', 'h_index': 9},
#  {'Author': 'Amanda Jones', 'h_index': 9},
#  {'Author': 'Amanda Meyers', 'h_index': 9},
#  {'Author': 'Andrea Parker', 'h_index': 9},
#  {'Author': 'Anna Parker', 'h_index': 9},
#  {'Author': 'Bailey Wilson', 'h_index': 9},
#  {'Author': 'Brett Parker', 'h_index': 9},
#  {'Author': 'Brian Chavez', 'h_index': 9},
#  {'Author': 'Caroline Gonzalez', 'h_index': 9},
#  {'Author': 'Carolyn Savage', 'h_index': 9},
#  {'Author': 'Cathy Hamilton', 'h_index': 9},
#  {'Author': 'Charles Mitchell', 'h_index': 9},
#  {'Author': 'Cheryl Schmitt', 'h_index': 9},
#  {'Author': 'Christy Manning', 'h_index': 9},
#  {'Author': 'Cody Jensen', 'h_index': 9},
#  {'Author': 'Cory Wheeler', 'h_index': 9},
#  {'Author': 'Crystal Green', 'h_index': 9},
#  {'Author': 'Cynthia Armstrong MD', 'h_index': 9},
#  {'Author': 'Daniel Castillo', 'h_index': 9},
#  {'Author': 'Darrell Webb', 'h_index': 9},
#  {'Author': 'Douglas Brown', 'h_index': 9},
#  {'Author': 'Dr. Donald Hale PhD', 'h_index': 9},
#  {'Author': 'Elijah Washington', 'h_index': 9},
#  {'Author': 'Erin Cochran', 'h_index': 9},
#  {'Author': 'Geoffrey Floyd DDS', 'h_index': 9},
#  {'Author': 'Harold Ortega', 'h_index': 9},
#  {'Author': 'Jacob Austin', 'h_index': 9},
#  {'Author': 'Jake Cook', 'h_index': 9},
#  {'Author': 'Jo Atkinson', 'h_index': 9},
#  {'Author': 'Joann Harris', 'h_index': 9},
#  {'Author': 'John Freeman', 'h_index': 9},
#  {'Author': 'John King', 'h_index': 9},
#  {'Author': 'John Wilson', 'h_index': 9},
#  {'Author': 'Joy Sanchez', 'h_index': 9},
#  {'Author': 'Karen Carpenter', 'h_index': 9},
#  {'Author': 'Karen Lawrence', 'h_index': 9},
#  {'Author': 'Kathy Jenkins', 'h_index': 9},
#  {'Author': 'Kimberly Garcia', 'h_index': 9},
#  {'Author': 'Linda Barrett', 'h_index': 9},
#  {'Author': 'Linda Gray', 'h_index': 9},
#  {'Author': 'Madison Evans', 'h_index': 9},
#  {'Author': 'Mary Anderson', 'h_index': 9},
#  {'Author': 'Max Garcia', 'h_index': 9},
#  {'Author': 'Melanie Guerra', 'h_index': 9},
#  {'Author': 'Melissa Coleman', 'h_index': 9},
#  {'Author': 'Michael Stevens', 'h_index': 9},
#  {'Author': 'Ms. Rita Gordon', 'h_index': 9},
#  {'Author': 'Natalie Townsend', 'h_index': 9},
#  {'Author': 'Nicholas Smith', 'h_index': 9},
#  {'Author': 'Patty Ballard', 'h_index': 9},
#  {'Author': 'Robert Barnes', 'h_index': 9},
#  {'Author': 'Robert Krueger', 'h_index': 9},
#  {'Author': 'Robert Scott', 'h_index': 9},
#  {'Author': 'Samantha Cain', 'h_index': 9},
#  {'Author': 'Sarah Navarro', 'h_index': 9},
#  {'Author': 'Shawn Wallace', 'h_index': 9},
#  {'Author': 'Stephen Smith', 'h_index': 9},
#  {'Author': 'Steven Gonzalez', 'h_index': 9},
#  {'Author': 'Steven Hernandez', 'h_index': 9},
#  {'Author': 'Steven Perry', 'h_index': 9},
#  {'Author': 'Sydney Potter', 'h_index': 9},
#  {'Author': 'Taylor Dunn', 'h_index': 9},
#  {'Author': 'Theresa Schmitt', 'h_index': 9},
#  {'Author': 'Thomas Kramer', 'h_index': 9},
#  {'Author': 'Thomas Wolf', 'h_index': 9},
#  {'Author': 'Timothy Campbell', 'h_index': 9},
#  {'Author': 'Tommy Morrison', 'h_index': 9},
#  {'Author': 'Tyler Brady', 'h_index': 9},
#  {'Author': 'Vicki Taylor', 'h_index': 9},
#  {'Author': 'Aaron Freeman', 'h_index': 8},
#  {'Author': 'Adam Charles', 'h_index': 8},
#  {'Author': 'Ashley Miller', 'h_index': 8},
#  {'Author': 'Chelsea Bauer', 'h_index': 8},
#  {'Author': 'Daisy Walker', 'h_index': 8},
#  {'Author': 'Daniel Mcbride', 'h_index': 8},
#  {'Author': 'Desiree Peck', 'h_index': 8},
#  {'Author': 'Diane Hawkins', 'h_index': 8},
#  {'Author': 'Emily Ball', 'h_index': 8},
#  {'Author': 'Felicia Jensen', 'h_index': 8},
#  {'Author': 'Jamie Moses', 'h_index': 8},
#  {'Author': 'Jessica Jackson', 'h_index': 8},
#  {'Author': 'Kathryn Wright', 'h_index': 8},
#  {'Author': 'Laura Gibson', 'h_index': 8},
#  {'Author': 'Lori Banks', 'h_index': 8},
#  {'Author': 'Marissa Clark', 'h_index': 8},
#  {'Author': 'Peter Thomas', 'h_index': 8},
#  {'Author': 'Rebecca Edwards', 'h_index': 8},
#  {'Author': 'Shelia Parker', 'h_index': 8},
#  {'Author': 'Timothy Hughes', 'h_index': 8},
#  {'Author': 'Zachary Johnson', 'h_index': 8},
#  {'Author': 'Jennifer White', 'h_index': 7}]
